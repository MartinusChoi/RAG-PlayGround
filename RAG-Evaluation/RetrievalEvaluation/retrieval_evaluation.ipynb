# %% [markdown]
# # Retrieval Evaluation Lab

# %% [markdown]
# ## Import Libraries & Basic Settings

# %%
# libraries
import os
import pandas as pd
import nest_asyncio
from dotenv import load_dotenv

from autorag.evaluator import Evaluator
# Out:
# None of PyTorch, TensorFlow >= 2.0, or Flax have been found. Models won't be available and only tokenizers, configuration and file/data utilities can be used.
# [05/23/25 08:39:50] INFO     [__init__.py:81] >> You are using API version of AutoRAG.To use local   ]8;id=934469;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/__init__.py\__init__.py]8;;\:]8;id=390483;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/__init__.py#81\81]8;;\
#                              version, run pip install 'AutoRAG[gpu]'
#                     INFO     [base.py:64] >> You are using API version of AutoRAG.To use local version,  ]8;id=177355;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/embedding/base.py\base.py]8;;\:]8;id=712656;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/embedding/base.py#64\64]8;;\
#                              run pip install 'AutoRAG[gpu]'

# %%
# dir path
root_dir = os.getcwd()
data_dir = os.path.join(root_dir, "data")
config_dir = os.path.join(root_dir, "config")
project_dir = os.path.join(root_dir, "autorag_project")

# %%
# nest asyncio
nest_asyncio.apply()

# %%
# set env value
load_dotenv()
# Out:
# True

# %% [markdown]
# ## Set Data

# %%
corpus_path = os.path.join(data_dir, "corpus.parquet")
qa_path = os.path.join(data_dir, "qa.parquet")
config_path = os.path.join(config_dir, "retrieval.yaml")

# %% [markdown]
# ## Run Retrieval Evaluation (AutoRAG)

# %%
evaluator = Evaluator(
    qa_data_path = qa_path,
    corpus_data_path = corpus_path,
    project_dir=project_dir
)

# %%
evaluator.start_trial(config_path)
# Out:
# [05/23/25 08:41:25] INFO     [evaluator.py:127] >>                                                 ]8;id=907274;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/evaluator.py\evaluator.py]8;;\:]8;id=640271;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/evaluator.py#127\127]8;;\
#                                              _        _____            _____
#                                   /\        | |      |  __ \     /\   / ____|
#                                  /  \  _   _| |_ ___ | |__) |   /  \ | |  __
#                                 / /\ \| | | | __/ _ \|  _  /   / /\ \| | |_ |
#                                / ____ \ |_| | || (_) | | \ \  / ____ \ |__| |
#                               /_/    \_\__,_|\__\___/|_|  \_\/_/    \_\_____|
#                     INFO     [evaluator.py:128] >> Start Validation input data and config YAML     ]8;id=163697;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/evaluator.py\evaluator.py]8;;\:]8;id=915324;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/evaluator.py#128\128]8;;\
#                              file first. If you want to skip this, put the --skip_validation flag
#                              or `skip_validation` at the start_trial function.
# Output()
#                     INFO     [posthog.py:22] >> Anonymized telemetry enabled. See                     ]8;id=852715;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/telemetry/product/posthog.py\posthog.py]8;;\:]8;id=44548;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/telemetry/product/posthog.py#22\22]8;;\
#                              https://docs.trychroma.com/telemetry for more information.
# [05/23/25 08:41:26] INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=425494;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=416016;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [evaluator.py:205] >> Running node line retrieve_node_line...         ]8;id=864525;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/evaluator.py\evaluator.py]8;;\:]8;id=752916;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/evaluator.py#205\205]8;;\
#                     INFO     [node.py:55] >> Running node retrieval...                                   ]8;id=797553;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/schema/node.py\node.py]8;;\:]8;id=511135;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/schema/node.py#55\55]8;;\
#                     INFO     [run.py:165] >> Running retrieval node - semantic retrieval module...       ]8;id=531974;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/run.py\run.py]8;;\:]8;id=838209;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/run.py#165\165]8;;\
#                     INFO     [base.py:18] >> Initialize retrieval node - VectorDB                        ]8;id=74393;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=480787;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#18\18]8;;\
#                     INFO     [base.py:31] >> Running retrieval node - VectorDB module...                 ]8;id=541900;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=441656;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#31\31]8;;\
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=414285;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=7336;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=872370;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=545010;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=267509;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=286037;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=637300;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=428288;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# [05/23/25 08:41:27] INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=802187;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=202349;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [base.py:28] >> Deleting retrieval node - VectorDB module...                ]8;id=417873;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=360517;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#28\28]8;;\
#                     INFO     [base.py:18] >> Initialize retrieval node - VectorDB                        ]8;id=888536;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=140781;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#18\18]8;;\
#                     INFO     [base.py:31] >> Running retrieval node - VectorDB module...                 ]8;id=485320;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=992722;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#31\31]8;;\
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=104429;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=297033;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=104542;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=744827;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=469635;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=349332;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=558370;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=72919;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=334885;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=885876;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [base.py:28] >> Deleting retrieval node - VectorDB module...                ]8;id=355827;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=37430;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#28\28]8;;\
#                     INFO     [base.py:18] >> Initialize retrieval node - VectorDB                        ]8;id=278476;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=231364;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#18\18]8;;\
#                     INFO     [base.py:31] >> Running retrieval node - VectorDB module...                 ]8;id=467679;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=393283;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#31\31]8;;\
# [05/23/25 08:41:28] INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=364763;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=165216;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=287106;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=385492;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=827330;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=385698;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=368320;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=149604;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=604145;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=920044;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [base.py:28] >> Deleting retrieval node - VectorDB module...                ]8;id=738886;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=260256;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#28\28]8;;\
#                     INFO     [base.py:18] >> Initialize retrieval node - VectorDB                        ]8;id=229074;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=677224;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#18\18]8;;\
#                     INFO     [base.py:31] >> Running retrieval node - VectorDB module...                 ]8;id=121532;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=29598;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#31\31]8;;\
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=70219;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=912214;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=360878;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=660547;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=117037;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=470303;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=654848;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=200713;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=173292;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=966393;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [base.py:28] >> Deleting retrieval node - VectorDB module...                ]8;id=146515;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=817442;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#28\28]8;;\
#                     INFO     [base.py:18] >> Initialize retrieval node - VectorDB                        ]8;id=45561;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=453550;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#18\18]8;;\
#                     INFO     [base.py:31] >> Running retrieval node - VectorDB module...                 ]8;id=677144;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=911093;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#31\31]8;;\
# [05/23/25 08:41:29] INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=987984;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=556040;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=248279;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=245048;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=953176;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=501684;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=368462;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=713745;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=997098;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=749422;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [base.py:28] >> Deleting retrieval node - VectorDB module...                ]8;id=858243;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=747274;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#28\28]8;;\
#                     INFO     [base.py:18] >> Initialize retrieval node - VectorDB                        ]8;id=699893;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=483660;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#18\18]8;;\
#                     INFO     [base.py:31] >> Running retrieval node - VectorDB module...                 ]8;id=165638;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=140071;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#31\31]8;;\
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=319575;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=83236;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=284934;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=80706;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=274196;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=130709;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=626664;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=36411;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=824982;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=151297;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [base.py:28] >> Deleting retrieval node - VectorDB module...                ]8;id=226718;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=755928;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#28\28]8;;\
#                     INFO     [base.py:18] >> Initialize retrieval node - VectorDB                        ]8;id=473117;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=979079;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#18\18]8;;\
#                     INFO     [base.py:31] >> Running retrieval node - VectorDB module...                 ]8;id=361158;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=808686;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#31\31]8;;\
# [05/23/25 08:41:30] INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=741308;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=355602;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=632875;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=300129;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=825329;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=383335;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     WARNING  [local_persistent_hnsw.py:423] >> Number of requested     ]8;id=10485;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py\local_persistent_hnsw.py]8;;\:]8;id=650253;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py#423\423]8;;\
#                              results 10 is greater than number of elements in index 5,
#                              updating n_results = 5
#                     WARNING  [local_persistent_hnsw.py:423] >> Number of requested     ]8;id=331586;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py\local_persistent_hnsw.py]8;;\:]8;id=823459;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py#423\423]8;;\
#                              results 10 is greater than number of elements in index 5,
#                              updating n_results = 5
#                     WARNING  [local_persistent_hnsw.py:423] >> Number of requested     ]8;id=93112;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py\local_persistent_hnsw.py]8;;\:]8;id=76468;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py#423\423]8;;\
#                              results 10 is greater than number of elements in index 5,
#                              updating n_results = 5
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=96382;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=923955;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     WARNING  [local_persistent_hnsw.py:423] >> Number of requested     ]8;id=532371;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py\local_persistent_hnsw.py]8;;\:]8;id=880068;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py#423\423]8;;\
#                              results 10 is greater than number of elements in index 5,
#                              updating n_results = 5
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=511046;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=626378;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     WARNING  [local_persistent_hnsw.py:423] >> Number of requested     ]8;id=302566;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py\local_persistent_hnsw.py]8;;\:]8;id=429874;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py#423\423]8;;\
#                              results 10 is greater than number of elements in index 5,
#                              updating n_results = 5
#                     INFO     [base.py:28] >> Deleting retrieval node - VectorDB module...                ]8;id=308417;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=554691;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#28\28]8;;\
#                     INFO     [base.py:18] >> Initialize retrieval node - VectorDB                        ]8;id=923569;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=69173;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#18\18]8;;\
#                     INFO     [base.py:31] >> Running retrieval node - VectorDB module...                 ]8;id=54091;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=203807;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#31\31]8;;\
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=979615;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=364016;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     WARNING  [local_persistent_hnsw.py:423] >> Number of requested     ]8;id=275874;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py\local_persistent_hnsw.py]8;;\:]8;id=901914;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py#423\423]8;;\
#                              results 10 is greater than number of elements in index 5,
#                              updating n_results = 5
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=760699;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=549511;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     WARNING  [local_persistent_hnsw.py:423] >> Number of requested     ]8;id=899478;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py\local_persistent_hnsw.py]8;;\:]8;id=169594;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py#423\423]8;;\
#                              results 10 is greater than number of elements in index 5,
#                              updating n_results = 5
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=505109;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=14984;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     WARNING  [local_persistent_hnsw.py:423] >> Number of requested     ]8;id=512322;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py\local_persistent_hnsw.py]8;;\:]8;id=450924;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py#423\423]8;;\
#                              results 10 is greater than number of elements in index 5,
#                              updating n_results = 5
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=67401;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=468390;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     WARNING  [local_persistent_hnsw.py:423] >> Number of requested     ]8;id=478807;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py\local_persistent_hnsw.py]8;;\:]8;id=623013;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py#423\423]8;;\
#                              results 10 is greater than number of elements in index 5,
#                              updating n_results = 5
# [05/23/25 08:41:31] INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=489352;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=790201;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     WARNING  [local_persistent_hnsw.py:423] >> Number of requested     ]8;id=959641;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py\local_persistent_hnsw.py]8;;\:]8;id=941724;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py#423\423]8;;\
#                              results 10 is greater than number of elements in index 5,
#                              updating n_results = 5
#                     INFO     [base.py:28] >> Deleting retrieval node - VectorDB module...                ]8;id=896037;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=217256;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#28\28]8;;\
#                     INFO     [base.py:18] >> Initialize retrieval node - VectorDB                        ]8;id=535425;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=279263;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#18\18]8;;\
#                     INFO     [base.py:31] >> Running retrieval node - VectorDB module...                 ]8;id=448738;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=98222;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#31\31]8;;\
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=663506;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=216294;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     WARNING  [local_persistent_hnsw.py:423] >> Number of requested     ]8;id=27302;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py\local_persistent_hnsw.py]8;;\:]8;id=532663;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py#423\423]8;;\
#                              results 50 is greater than number of elements in index 5,
#                              updating n_results = 5
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=578691;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=784204;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     WARNING  [local_persistent_hnsw.py:423] >> Number of requested     ]8;id=755897;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py\local_persistent_hnsw.py]8;;\:]8;id=545687;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py#423\423]8;;\
#                              results 50 is greater than number of elements in index 5,
#                              updating n_results = 5
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=943599;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=879259;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     WARNING  [local_persistent_hnsw.py:423] >> Number of requested     ]8;id=883428;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py\local_persistent_hnsw.py]8;;\:]8;id=141702;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py#423\423]8;;\
#                              results 50 is greater than number of elements in index 5,
#                              updating n_results = 5
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=222782;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=698179;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     WARNING  [local_persistent_hnsw.py:423] >> Number of requested     ]8;id=912229;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py\local_persistent_hnsw.py]8;;\:]8;id=435044;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py#423\423]8;;\
#                              results 50 is greater than number of elements in index 5,
#                              updating n_results = 5
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=8166;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=324558;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     WARNING  [local_persistent_hnsw.py:423] >> Number of requested     ]8;id=379430;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py\local_persistent_hnsw.py]8;;\:]8;id=293686;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py#423\423]8;;\
#                              results 50 is greater than number of elements in index 5,
#                              updating n_results = 5
#                     INFO     [base.py:28] >> Deleting retrieval node - VectorDB module...                ]8;id=74460;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=364553;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#28\28]8;;\
#                     INFO     [base.py:18] >> Initialize retrieval node - VectorDB                        ]8;id=699420;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=67755;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#18\18]8;;\
#                     INFO     [base.py:31] >> Running retrieval node - VectorDB module...                 ]8;id=348478;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=215548;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#31\31]8;;\
# [05/23/25 08:41:32] INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=504420;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=35657;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     WARNING  [local_persistent_hnsw.py:423] >> Number of requested     ]8;id=704253;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py\local_persistent_hnsw.py]8;;\:]8;id=577894;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py#423\423]8;;\
#                              results 50 is greater than number of elements in index 5,
#                              updating n_results = 5
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=178349;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=110637;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     WARNING  [local_persistent_hnsw.py:423] >> Number of requested     ]8;id=157747;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py\local_persistent_hnsw.py]8;;\:]8;id=885505;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py#423\423]8;;\
#                              results 50 is greater than number of elements in index 5,
#                              updating n_results = 5
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=588060;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=398453;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     WARNING  [local_persistent_hnsw.py:423] >> Number of requested     ]8;id=849594;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py\local_persistent_hnsw.py]8;;\:]8;id=299327;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py#423\423]8;;\
#                              results 50 is greater than number of elements in index 5,
#                              updating n_results = 5
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=683677;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=386646;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     WARNING  [local_persistent_hnsw.py:423] >> Number of requested     ]8;id=940302;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py\local_persistent_hnsw.py]8;;\:]8;id=144675;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py#423\423]8;;\
#                              results 50 is greater than number of elements in index 5,
#                              updating n_results = 5
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=857822;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=919152;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     WARNING  [local_persistent_hnsw.py:423] >> Number of requested     ]8;id=996331;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py\local_persistent_hnsw.py]8;;\:]8;id=461916;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/segment/impl/vector/local_persistent_hnsw.py#423\423]8;;\
#                              results 50 is greater than number of elements in index 5,
#                              updating n_results = 5
#                     INFO     [base.py:28] >> Deleting retrieval node - VectorDB module...                ]8;id=38629;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py\base.py]8;;\:]8;id=318787;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/base.py#28\28]8;;\
#                     INFO     [run.py:196] >> Running retrieval node - lexical retrieval module...        ]8;id=348542;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/run.py\run.py]8;;\:]8;id=541822;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/run.py#196\196]8;;\
#                     INFO     [run.py:227] >> Running retrieval node - hybrid retrieval module...         ]8;id=944626;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/run.py\run.py]8;;\:]8;id=716730;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/run.py#227\227]8;;\
#                     INFO     [evaluator.py:218] >> Evaluation complete.                            ]8;id=377477;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/evaluator.py\evaluator.py]8;;\:]8;id=807061;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/evaluator.py#218\218]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#                     INFO     [validator.py:98] >> Validation complete.                              ]8;id=184025;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/validator.py\validator.py]8;;\:]8;id=980816;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/validator.py#98\98]8;;\
# Output()
#                     INFO     [posthog.py:22] >> Anonymized telemetry enabled. See                     ]8;id=518978;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/telemetry/product/posthog.py\posthog.py]8;;\:]8;id=280920;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/chromadb/telemetry/product/posthog.py#22\22]8;;\
#                              https://docs.trychroma.com/telemetry for more information.
# [05/23/25 08:41:33] INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=318695;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=965292;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# [05/23/25 08:41:35] INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=392046;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=114171;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# [05/23/25 08:41:37] INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=625605;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=934068;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# [05/23/25 08:41:39] INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=712824;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=576739;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# ...
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=538428;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=451136;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=200394;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=671745;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=675402;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=279951;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=960681;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=258317;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=602884;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=351765;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=256709;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=498193;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=88954;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=942282;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=256726;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=227473;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=186933;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=712473;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=836579;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=257073;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=956073;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=915375;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=479270;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=421457;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=504130;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=238336;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=198551;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=782689;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=453275;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=737715;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=918314;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=288394;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=127534;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=523265;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=522204;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=686285;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=346362;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=130357;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=637994;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=144869;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=547638;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=526581;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=472209;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=627254;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=812752;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=385567;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=129340;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=667463;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=932668;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=724547;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=836925;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=553677;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=206733;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=119368;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=698259;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=298215;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=781510;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=30372;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=195741;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=311348;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=472428;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=285893;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=493577;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=524599;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=473527;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=940802;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=89286;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=917846;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=432262;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=813421;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=991389;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=41518;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
# [05/23/25 08:43:31] INFO     [_client.py:1786] >> HTTP Request: POST                                ]8;id=468999;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=919252;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/httpx/_client.py#1786\1786]8;;\
#                              https://api.openai.com/v1/embeddings "HTTP/1.1 200 OK"
#                     INFO     [run.py:196] >> Running retrieval node - lexical retrieval module...        ]8;id=614234;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/run.py\run.py]8;;\:]8;id=538944;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/run.py#196\196]8;;\
#                     INFO     [run.py:227] >> Running retrieval node - hybrid retrieval module...         ]8;id=626796;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/run.py\run.py]8;;\:]8;id=964890;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/nodes/retrieval/run.py#227\227]8;;\
#                     INFO     [evaluator.py:218] >> Evaluation complete.                            ]8;id=679589;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/evaluator.py\evaluator.py]8;;\:]8;id=376241;file:///opt/anaconda3/envs/llm/lib/python3.10/site-packages/autorag/evaluator.py#218\218]8;;\
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
result_path = os.path.join(project_dir, "0", "retrieve_node_line", 'retrieval', "summary.csv")

result = pd.read_csv(result_path)

# %%
result
# Out:
#     filename module_name                                      module_params  \
# 0  0.parquet    VectorDB  {'top_k': 1, 'embedding_model': 'openai_embed_...
# 1  1.parquet    VectorDB          {'top_k': 1, 'embedding_model': 'openai'}
# 2  2.parquet    VectorDB  {'top_k': 3, 'embedding_model': 'openai_embed_...
# 3  3.parquet    VectorDB          {'top_k': 3, 'embedding_model': 'openai'}
# 4  4.parquet    VectorDB  {'top_k': 5, 'embedding_model': 'openai_embed_...
# 5  5.parquet    VectorDB          {'top_k': 5, 'embedding_model': 'openai'}
# 6  6.parquet    VectorDB  {'top_k': 10, 'embedding_model': 'openai_embed...
# 7  7.parquet    VectorDB         {'top_k': 10, 'embedding_model': 'openai'}
# 8  8.parquet    VectorDB  {'top_k': 50, 'embedding_model': 'openai_embed...
# 9  9.parquet    VectorDB         {'top_k': 50, 'embedding_model': 'openai'}
#
#    execution_time  retrieval_f1  retrieval_recall  retrieval_precision  \
# 0        0.009660      0.500000          0.500000             0.500000
# 1        0.048092      0.500000          0.500000             0.500000
# 2        0.036269      0.364035          0.728070             0.242690
# 3        0.064886      0.364035          0.728070             0.242690
# 4        0.015368      0.269006          0.807018             0.161404
# 5        0.082586      0.269006          0.807018             0.161404
# 6        0.053473      0.162679          0.894737             0.089474
# 7        0.536113      0.162679          0.894737             0.089474
# 8        0.036454      0.037496          0.956140             0.019123
# 9        0.031339      0.037496          0.956140             0.019123
#
#    retrieval_map  retrieval_mrr  retrieval_ndcg  is_best
# 0       0.500000       0.500000        0.500000    False
# 1       0.500000       0.500000        0.500000    False
# 2       0.600877       0.600877        0.633560     True
# 3       0.600877       0.600877        0.633560    False
# 4       0.620029       0.620029        0.667015    False
# 5       0.619298       0.619298        0.666407    False
# 6       0.631986       0.631986        0.695779    False
# 7       0.631986       0.631986        0.695779    False
# 8       0.635090       0.635090        0.709672    False
# 9       0.635090       0.635090        0.709672    False

# %%
features = [
    "module_params",
    "execution_time",
    "retrieval_f1",
    "retrieval_recall",
    "retrieval_precision",
    "retrieval_map",
    "retrieval_mrr",
    "retrieval_ndcg"
]

result[features]
# Out:
#                                        module_params  execution_time  \
# 0  {'top_k': 1, 'embedding_model': 'openai_embed_...        0.009660
# 1          {'top_k': 1, 'embedding_model': 'openai'}        0.048092
# 2  {'top_k': 3, 'embedding_model': 'openai_embed_...        0.036269
# 3          {'top_k': 3, 'embedding_model': 'openai'}        0.064886
# 4  {'top_k': 5, 'embedding_model': 'openai_embed_...        0.015368
# 5          {'top_k': 5, 'embedding_model': 'openai'}        0.082586
# 6  {'top_k': 10, 'embedding_model': 'openai_embed...        0.053473
# 7         {'top_k': 10, 'embedding_model': 'openai'}        0.536113
# 8  {'top_k': 50, 'embedding_model': 'openai_embed...        0.036454
# 9         {'top_k': 50, 'embedding_model': 'openai'}        0.031339
#
#    retrieval_f1  retrieval_recall  retrieval_precision  retrieval_map  \
# 0      0.500000          0.500000             0.500000       0.500000
# 1      0.500000          0.500000             0.500000       0.500000
# 2      0.364035          0.728070             0.242690       0.600877
# 3      0.364035          0.728070             0.242690       0.600877
# 4      0.269006          0.807018             0.161404       0.620029
# 5      0.269006          0.807018             0.161404       0.619298
# 6      0.162679          0.894737             0.089474       0.631986
# 7      0.162679          0.894737             0.089474       0.631986
# 8      0.037496          0.956140             0.019123       0.635090
# 9      0.037496          0.956140             0.019123       0.635090
#
#    retrieval_mrr  retrieval_ndcg
# 0       0.500000        0.500000
# 1       0.500000        0.500000
# 2       0.600877        0.633560
# 3       0.600877        0.633560
# 4       0.620029        0.667015
# 5       0.619298        0.666407
# 6       0.631986        0.695779
# 7       0.631986        0.695779
# 8       0.635090        0.709672
# 9       0.635090        0.709672
